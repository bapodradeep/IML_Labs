# %%
#Developed By :- Deep Bapodra
#Enrollment :- 216270307077
#practical 2:Write a NumPy program to implement following operation
#• to convert a list of numeric values into a one-dimensional NumPy array

import numpy as np

x=[1,2,3,4,5,6]

a=np.array(x)
print("array is:",a)

# %%
#Developed By :- Deep Bapodra
#Enrollment :- 216270307077
#practical 2:Write a NumPy program to implement following operation
#to create a 3x3 matrix with values ranging from 2 to 10

import numpy as np

a=np.array([[[2,2,3],[4,5,6],[7,8,9]]])

print("3x3 matrix is:",a)

# %%
#Developed By :- Deep Bapodra
#Enrollment :- 216270307077
#practical 2:Write a NumPy program to implement following operation
#to append values at the end of an array

import numpy as np

a=np.array([11,12,13,14,15])

print("array is:",a)

b= np.append(a,69)

print("updated array is:",b)

# %%
# Program By:-Deep Bapodra
# Enrollment :-216270307077

a2 = np.array([[1., 2, 3],
               [4, 5, 6]])
print("a2: \n", a2)

print("\nNumber of axes/dimensions in the array: ", a2.ndim)
print("Shape of the array: ", a2.shape)
print("Size of the array/Number of Elements in the: ", a2.size)
print("Type of the elements in the array: ", a2.dtype)
print("Size of the elements in the array: ", a2.itemsize)
print("Buffer containing the array: ", a2.data)
