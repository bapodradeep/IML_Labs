# %%
# Pratical 3:- Write a NumPy program to implement following operation
# to split an array of 14 elements into 3 arrats each with 2,4, and 8 elements in the original order

#Program By: Deep Bapodra
#Enrollment: 216270307077

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import numpy as np 

array1 = np.arange(14)
print(array1)
print(" 2 element array",array1[:2])
print(" 4 element array",array1[2:6])
print(" 8 element array",array1[6:14])

# %%
#Pratical 3:-Write a NumPy program to implement following operation
#to stack arrays horizontally (column wise)
#Program By:-Deep Bapodra
#Enrollment :- 216270307077
import numpy as np

array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

result = np.hstack((array1, array2))

print(result)
